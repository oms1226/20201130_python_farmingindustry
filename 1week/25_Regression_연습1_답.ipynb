# %% [markdown]
# # Regression 연습1 : Boston House Price
#
# #### 머신러닝 코드 구조 <br>
#
# ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ## 00 환경준비

# %% [markdown]
# ### 01.Import

# %%
#라이브러리들을 불러오자.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ### 02.Data Loading

# %%
data_path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv'
data = pd.read_csv(data_path)

# %% [markdown]
# * data set 설명
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * medv : target
# * chas : 범주형.(그러나 이미 1,0이므로 더미변수로 만들 필요 없음)

# %% [markdown]
# ## 10.데이터 이해
#
# ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ### 11.둘러보기

# %%
# 상/하위 몇개 행을 살펴 봅시다.

data.head()
data.tail()
# Out:
#         crim   zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 501  0.06263  0.0  11.93     0  0.573  ...  273     21.0  391.99   9.67  22.4
# 502  0.04527  0.0  11.93     0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076  0.0  11.93     0  0.573  ...  273     21.0  396.90   5.64  23.9
# 504  0.10959  0.0  11.93     0  0.573  ...  273     21.0  393.45   6.48  22.0
# 505  0.04741  0.0  11.93     0  0.573  ...  273     21.0  396.90   7.88  11.9
#
# [5 rows x 14 columns]

# %%
# 각 칼럼의 타입을 살펴 봅시다.

data.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
# 행, 열의 개수를 살펴 봅시다.
data.shape
# Out:
# (506, 14)

# %% [markdown]
# ### 12.기초통계량

# %%
# 숫자형 변수들의 통계량을 살펴 봅니다.
data.describe()
# Out:
#              crim          zn       indus  ...       black       lstat        medv
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
# 각 변수별 NaN 현황 파악하기
data.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ### 13.탐색하기

# %%
# indus와 medv의 관계를 산점도로 그려봅시다.
# 비소매상업지역 면적
data.plot(kind = 'scatter', x='indus', y='medv', figsize = (15,8))

# %%
# crim과 medv의 관계를 산점도로 그려봅시다.
# 범죄율
data.plot(kind = 'scatter', x='crim', y='medv', figsize = (15,8))

# %%
# 위 두 변수 이외에도 2개 정도를 더 살펴봅시다.
# 방수
data.plot(kind = 'scatter', x='rm', y='medv', figsize = (15,8))

# %%
# 일산화질소 농도
data.plot(kind = 'scatter', x='nox', y='medv', figsize = (15,8))

# %% [markdown]
# ## 20.데이터 준비
#
# ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ### 21.변수 정리

# %% [markdown]
# ### 22.NA 처리

# %% [markdown]
# ### 23.Feature Engineering

# %% [markdown]
# ### 24.Dummy Variable
#
#
# 익혀야 할 방법들
# pd.get_dummies, pd.concat, (Pandas Dataframe).drop

# %% [markdown]
# ### 25.Data Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('medv', axis = 1)
y = data.loc[:,'medv']

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=.2, random_state = 1234)

# %% [markdown]
# ### 26.Scaling features

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(train_x)

train_x = scaler.transform(train_x)
test_x = scaler.transform(test_x)

# %% [markdown]
# ### 27.Dataframe to Numpy array

# %% [markdown]
# ## 30.모델링
#
# # ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ### 선형회귀분석으로 모델링을 수행해 봅시다.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
model_lm = LinearRegression()
model_lm.fit(train_x, train_y)
test_pred_lm = model_lm.predict(test_x)

# %% [markdown]
# ### knn으로 모델링을 수행해 봅시다.

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_knn = KNeighborsRegressor()
model_knn.fit(train_x, train_y)
test_pred_knn = model_knn.predict(test_x)

# %%
for k in range(3,21) :
    model_knn = KNeighborsRegressor(n_neighbors=k)
    model_knn.fit(train_x, train_y)
    test_pred_knn = model_knn.predict(test_x)
    print('k : {}, RMSE : {}'.format(k,mean_squared_error(test_y, test_pred_knn, squared=0).round(3)))
# Out:
# k : 3, RMSE : 4.669
# k : 4, RMSE : 5.328
# k : 5, RMSE : 5.345
# k : 6, RMSE : 5.252
# k : 7, RMSE : 5.349
# k : 8, RMSE : 5.467
# k : 9, RMSE : 5.467
# k : 10, RMSE : 5.603
# k : 11, RMSE : 5.72
# k : 12, RMSE : 5.788
# k : 13, RMSE : 5.818
# k : 14, RMSE : 5.943
# k : 15, RMSE : 5.985
# k : 16, RMSE : 6.006
# k : 17, RMSE : 6.094
# k : 18, RMSE : 6.104
# k : 19, RMSE : 6.159
# k : 20, RMSE : 6.18

# %%
# k가 6일때 오차가 가장 낮음
model_knn = KNeighborsRegressor(n_neighbors=3)
model_knn.fit(train_x, train_y)
test_pred_knn = model_knn.predict(test_x)

# %% [markdown]
# ### 선형회귀분석과 knn 결과를 비교해 봅시다.

# %%
# MAPE 함수 만들기
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))

# %%
print('LM RMSE : {}'.format(mean_squared_error(test_y, test_pred_lm, squared=0).round(3)))
print('KNN RMSE : {}'.format(mean_squared_error(test_y, test_pred_knn, squared=0).round(3)))
print('---------------------------')
print('LM MAPE : {}'.format(mean_absolute_percentage_error(test_y, test_pred_lm).round(3)))
print('KNN MAPE : {}'.format(mean_absolute_percentage_error(test_y, test_pred_knn).round(3)))
# Out:
# LM RMSE : 4.895
# KNN RMSE : 4.669
# ---------------------------
# LM MAPE : 0.169
# KNN MAPE : 0.171

# %%
# 실제값, 선형회귀 예측값, KNN 예측값을 눈으로 봅시다.
result = {'y':test_y, 'y_lm':test_pred_lm.round(1), 'y_knn':test_pred_knn.round(1)}

pd.DataFrame(result)
# Out:
#         y  y_lm  y_knn
# 64   33.0  21.3   28.6
# 100  27.5  23.9   22.0
# 400   5.6  12.3   11.3
# 485  21.2  22.1   21.0
# 454  14.9  14.2   12.4
# ..    ...   ...    ...
# 350  22.9  19.2   24.6
# 191  30.5  30.0   33.9
# 239  23.3  28.1   22.6
# 109  19.4  19.5   19.9
# 219  23.0  29.8   25.3
#
# [102 rows x 3 columns]
