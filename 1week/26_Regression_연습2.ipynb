# %% [markdown]
# # Regression 연습2 : white wine quality
#
# #### 머신러닝 코드 구조 <br>
#
# ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ## 00 환경준비

# %% [markdown]
# ### 01.Import

# %%
#라이브러리들을 불러오자.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ### 02.Data Loading

# %%
wine = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/winequality-white2.csv')
wine.drop('quality1', axis = 1, inplace = True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 10.데이터 이해
#
# ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ### 11.둘러보기

# %%
# 상/하위 몇개 행을 살펴 봅시다.

# %%
# 각 칼럼의 타입을 살펴 봅시다.

# %%
# 행, 열의 개수를 살펴 봅시다.

# %% [markdown]
# ### 12.기초통계량

# %%
# 숫자형 변수들의 통계량을 살펴 봅니다.

# %%
# 각 변수별 NaN 현황 파악하기

# %% [markdown]
# ### 13.탐색하기

# %%
# feature 4개를 선정하고, quality2와 비교하는 산점도를 그리시오.

# %%
# 가장 강한 상관관계가 있는 변수는 무엇인가요?

# %% [markdown]
# ## 20.데이터 준비
#
# ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ### 21.변수 정리

# %% [markdown]
# ### 22.NA 처리
#
# (아래에서 knn imputation으로 처리할 겁입니다.)

# %% [markdown]
# ### 23.Feature Engineering

# %% [markdown]
# ### 24.Dummy Variable
#
#
# 익혀야 할 방법들
# pd.get_dummies, pd.concat, (Pandas Dataframe).drop

# %% [markdown]
# ### 25.Data Split

# %% [markdown]
# ### (Again)22.NA 처리 : knn Imputation

# %% [markdown]
# ### 26.Scaling features

# %% [markdown]
# ### 27.Dataframe to Numpy array

# %% [markdown]
# ## 30.모델링
#
# # ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %% [markdown]
# ### 선형회귀분석으로 모델링을 수행해 봅시다.

# %% [markdown]
# ### knn으로 모델링을 수행해 봅시다.

# %% [markdown]
# ### 선형회귀분석과 knn 결과를 비교해 봅시다.

# %%
# MAPE 함수입니다. 생성해서 사용해 봅시다.
from sklearn.utils import check_arrays
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = check_arrays(y_true, y_pred)

    ## Note: does not handle mix 1d representation
    #if _is_1d(y_true): 
    #    y_true, y_pred = _check_1d_array(y_true, y_pred)

    return np.mean(np.abs((y_true - y_pred) / y_true))
